# %% [markdown]
# # Data Cleaning and Feature Engineering
#
# Data source: https://www.kaggle.com/datasets/apoorvwatsky/supply-chain-shipment-pricing-data
#
# Reporter: Trinh Nguyen

# %% [markdown]
# ### Introduction
# This notebook focuses on cleaning, standardizing, and preparing the raw logistics dataset for analysis.
# Key objectives include data validation, handling inconsistencies, and creating derived features required for downstream exploratory and performance analysis.

# %% [markdown]
# ### Data cleaning

# %%
# Load data
import pandas as pd

df_raw = pd.read_csv("../Data/SCMS_Delivery_History_Dataset_20150929.csv", encoding="latin1")
df_raw.head()

# Standardize column names
list(df_raw.columns)

df_raw.columns = (df_raw.columns.str.strip().str.replace(" ", "_").str.replace("/", "_").str.lower())

df = df_raw.copy()
list(df.columns)
# Out:
# ['id',
#  'project_code',
#  'pq_#',
#  'po___so_#',
#  'asn_dn_#',
#  'country',
#  'managed_by',
#  'fulfill_via',
#  'vendor_inco_term',
#  'shipment_mode',
#  'pq_first_sent_to_client_date',
#  'po_sent_to_vendor_date',
#  'scheduled_delivery_date',
#  'delivered_to_client_date',
#  'delivery_recorded_date',
#  'product_group',
#  'sub_classification',
#  'vendor',
#  'item_description',
#  'molecule_test_type',
#  'brand',
#  'dosage',
#  'dosage_form',
#  'unit_of_measure_(per_pack)',
#  'line_item_quantity',
#  'line_item_value',
#  'pack_price',
#  'unit_price',
#  'manufacturing_site',
#  'first_line_designation',
#  'weight_(kilograms)',
#  'freight_cost_(usd)',
#  'line_item_insurance_(usd)']

# %%
# Import neccesary libraries

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Convert date columns
df["po_sent_to_vendor_date_raw"] = df['po_sent_to_vendor_date']
df["pq_first_sent_to_client_date_raw"] = df["pq_first_sent_to_client_date"]

date_cols = ['pq_first_sent_to_client_date', 'po_sent_to_vendor_date', 'scheduled_delivery_date', 'delivered_to_client_date', 'delivery_recorded_date']

for col in date_cols:
    df[col] = pd.to_datetime(df[col], errors='coerce')

df[date_cols]
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_23388\2494101729.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# C:\Users\ACER\AppData\Local\Temp\ipykernel_23388\2494101729.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# C:\Users\ACER\AppData\Local\Temp\ipykernel_23388\2494101729.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# C:\Users\ACER\AppData\Local\Temp\ipykernel_23388\2494101729.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
# C:\Users\ACER\AppData\Local\Temp\ipykernel_23388\2494101729.py:8: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors='coerce')
#       pq_first_sent_to_client_date po_sent_to_vendor_date  \
# 0                              NaT                    NaT
# 1                              NaT                    NaT
# 2                              NaT                    NaT
# 3                              NaT                    NaT
# 4                              NaT                    NaT
# ...                            ...                    ...
# 10319                   2014-10-16                    NaT
# 10320                   2014-10-24                    NaT
# 10321                   2014-08-12                    NaT
# 10322                   2015-07-01                    NaT
# 10323                   2014-10-16                    NaT
#
#       scheduled_delivery_date delivered_to_client_date delivery_recorded_date
# 0                  2006-06-02               2006-06-02             2006-06-02
# 1                  2006-11-14               2006-11-14             2006-11-14
# 2                  2006-08-27               2006-08-27             2006-08-27
# 3                  2006-09-01               2006-09-01             2006-09-01
# 4                  2006-08-11               2006-08-11             2006-08-11
# ...                       ...                      ...                    ...
# 10319              2015-07-31               2015-07-15             2015-07-20
# 10320              2015-07-31               2015-08-06             2015-08-07
# 10321              2015-08-31               2015-08-25             2015-09-03
# 10322              2015-09-09               2015-08-04             2015-08-11
# 10323              2015-08-31               2015-08-04             2015-08-11
#
# [10324 rows x 5 columns]

# %%
# Date logic checks
df["invalid_delivery"] = ((df["delivered_to_client_date"] < df["po_sent_to_vendor_date"]) |
                          (df["scheduled_delivery_date"] < df["po_sent_to_vendor_date"]))
df.loc[df["invalid_delivery"] == True]
# Out:
#          id project_code            pq_#    po___so_#   asn_dn_#  \
# 430    4190   116-ZA-T01  Pre-PQ Process   SCMS-14050   ASN-1252
# 454    4432   106-HT-T01  Pre-PQ Process   SCMS-22780   ASN-1680
# 2698  13148   103-DO-T30       FPQ-14469  SCMS-244720  ASN-26962
# 3387  25539   116-ZA-T30       FPQ-15950  SCMS-277981  ASN-32394
# 4906  52710   116-ZA-T30       FPQ-13973  SCMS-238571  ASN-26885
#
#                  country managed_by  fulfill_via vendor_inco_term  \
# 430         South Africa   PMO - US  Direct Drop              DDP
# 454                Haiti   PMO - US  Direct Drop              DDP
# 2698  Dominican Republic   PMO - US  Direct Drop              DDP
# 3387        South Africa   PMO - US  Direct Drop              DDP
# 4906        South Africa   PMO - US  Direct Drop              DDP
#
#      shipment_mode  ... pack_price unit_price            manufacturing_site  \
# 430            NaN  ...       5.99       0.10            BMS Meymac, France
# 454            Air  ...      85.00       0.85               Inverness Japan
# 2698           Air  ...      32.44       0.20  ABBVIE Labs North Chicago US
# 3387         Truck  ...       4.62       0.05        ABBVIE (Abbott) France
# 4906         Truck  ...      22.06       0.07     ABBVIE (Abbott) Logis. UK
#
#      first_line_designation          weight_(kilograms)  \
# 430                     Yes  Weight Captured Separately
# 454                     Yes  Weight Captured Separately
# 2698                    Yes  Weight Captured Separately
# 3387                    Yes  Weight Captured Separately
# 4906                    Yes  Weight Captured Separately
#
#                       freight_cost_(usd) line_item_insurance_(usd)  \
# 430   Freight Included in Commodity Cost                      7.67
# 454   Freight Included in Commodity Cost                      4.08
# 2698  Freight Included in Commodity Cost                    152.40
# 3387  Freight Included in Commodity Cost                      0.01
# 4906  Freight Included in Commodity Cost                      0.05
#
#      po_sent_to_vendor_date_raw pq_first_sent_to_client_date_raw  \
# 430                  11/12/2007                   Pre-PQ Process
# 454                   4/28/2008                   Pre-PQ Process
# 2698                  6/23/2014                        6/13/2014
# 3387                  5/29/2015                        2/20/2015
# 4906                  6/26/2014                        4/30/2014
#
#      invalid_delivery
# 430              True
# 454              True
# 2698             True
# 3387             True
# 4906             True
#
# [5 rows x 36 columns]

# %%
# Clean numeric columns
num_cols = df.select_dtypes(include=['number']).columns
print(num_cols)

for col in num_cols:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce')

df[num_cols].head(20)
# Out:
# Index(['id', 'unit_of_measure_(per_pack)', 'line_item_quantity',
#        'line_item_value', 'pack_price', 'unit_price',
#        'line_item_insurance_(usd)'],
#       dtype='object')
#     id  unit_of_measure_(per_pack)  line_item_quantity  line_item_value  \
# 0    1                          30                  19           551.00
# 1    3                         240                1000          6200.00
# 2    4                         100                 500         40000.00
# 3   15                          60               31920        127360.80
# 4   16                          60               38000        121600.00
# 5   23                         240                 416          2225.60
# 6   44                          90                 135          4374.00
# 7   45                          60               16667         60834.55
# 8   46                          60                 273           532.35
# 9   47                         120                2800        115080.00
# 10  60                         120                2800        115080.00
# 11  61                          20                2500        100000.00
# 12  62                         100                  10           850.00
# 13  64                          60               10000         99800.00
# 14  65                         100                 750         60000.00
# 15  68                          60                 579         14764.50
# 16  69                         100                1500        120000.00
# 17  80                          30                2000         33000.00
# 18  87                         200                 712          8964.08
# 19  92                         100                1000         80000.00
#
#     pack_price  unit_price  line_item_insurance_(usd)
# 0        29.00        0.97                        NaN
# 1         6.20        0.03                        NaN
# 2        80.00        0.80                        NaN
# 3         3.99        0.07                        NaN
# 4         3.20        0.05                        NaN
# 5         5.35        0.02                        NaN
# 6        32.40        0.36                        NaN
# 7         3.65        0.06                        NaN
# 8         1.95        0.03                        NaN
# 9        41.10        0.34                        NaN
# 10       41.10        0.34                        NaN
# 11       40.00        2.00                        NaN
# 12       85.00        0.85                        NaN
# 13        9.98        0.17                        NaN
# 14       80.00        0.80                        NaN
# 15       25.50        0.42                        NaN
# 16       80.00        0.80                      192.0
# 17       16.50        0.55                        NaN
# 18       12.59        0.06                        NaN
# 19       80.00        0.80                      128.0

# %%
# Clean and normalize categorical columns
cat_cols = df.select_dtypes(include="object").columns
df[cat_cols] = df[cat_cols].apply(lambda col: col.str.strip())
df["country"] = df["country"].str.title()
df["shipment_mode"] = df["shipment_mode"].str.title()
df["vendor"] = df["vendor"].str.title()

# %%
# Extract numeric values from Weight & Freight
df["weight_kg_numeric"] = pd.to_numeric(df["weight_(kilograms)"], errors = "coerce")
df["freight_cost_usd_numeric"] = pd.to_numeric(df["freight_cost_(usd)"], errors = "coerce")


df["asn_reference"] = df["weight_(kilograms)"].str.extract(r"See (ASN-\d+|DN-\d+)")
asn_weight_map = (df.loc[df["weight_kg_numeric"].notna(), ["asn_dn_#", "weight_kg_numeric"]].drop_duplicates(subset = "asn_dn_#"))
asn_freight_map = (df.loc[df["freight_cost_usd_numeric"].notna(), ["asn_dn_#", "freight_cost_usd_numeric"]].drop_duplicates(subset = "asn_dn_#"))
asn_freight_map

df = df.merge(asn_weight_map, on = "asn_dn_#", how = "left")
df = df.merge(asn_freight_map, on = "asn_dn_#", how = "left")
df
# Out:
#           id project_code            pq_# po___so_# asn_dn_#        country  \
# 0          1   100-CI-T01  Pre-PQ Process    SCMS-4    ASN-8  Côte D'Ivoire
# 1          3   108-VN-T01  Pre-PQ Process   SCMS-13   ASN-85        Vietnam
# 2          4   100-CI-T01  Pre-PQ Process   SCMS-20   ASN-14  Côte D'Ivoire
# 3         15   108-VN-T01  Pre-PQ Process   SCMS-78   ASN-50        Vietnam
# 4         16   108-VN-T01  Pre-PQ Process   SCMS-81   ASN-55        Vietnam
# ...      ...          ...             ...       ...      ...            ...
# 10319  86818   103-ZW-T30       FPQ-15197  SO-50020  DN-4307       Zimbabwe
# 10320  86819   104-CI-T30       FPQ-15259  SO-50102  DN-4313  Côte D'Ivoire
# 10321  86821   110-ZM-T30       FPQ-14784  SO-49600  DN-4316         Zambia
# 10322  86822   200-ZW-T30       FPQ-16523  SO-51680  DN-4334       Zimbabwe
# 10323  86823   103-ZW-T30       FPQ-15197  SO-50022  DN-4336       Zimbabwe
#
#       managed_by  fulfill_via vendor_inco_term shipment_mode  ...  \
# 0       PMO - US  Direct Drop              EXW           Air  ...
# 1       PMO - US  Direct Drop              EXW           Air  ...
# 2       PMO - US  Direct Drop              FCA           Air  ...
# 3       PMO - US  Direct Drop              EXW           Air  ...
# 4       PMO - US  Direct Drop              EXW           Air  ...
# ...          ...          ...              ...           ...  ...
# 10319   PMO - US     From RDC   N/A - From RDC         Truck  ...
# 10320   PMO - US     From RDC   N/A - From RDC         Truck  ...
# 10321   PMO - US     From RDC   N/A - From RDC         Truck  ...
# 10322   PMO - US     From RDC   N/A - From RDC         Truck  ...
# 10323   PMO - US     From RDC   N/A - From RDC         Truck  ...
#
#                        freight_cost_(usd) line_item_insurance_(usd)  \
# 0                                  780.34                       NaN
# 1                                  4521.5                       NaN
# 2                                 1653.78                       NaN
# 3                                16007.06                       NaN
# 4                                45450.08                       NaN
# ...                                   ...                       ...
# 10319             See DN-4307 (ID#:83920)                    705.79
# 10320             See DN-4313 (ID#:83921)                    161.71
# 10321  Freight Included in Commodity Cost                   5284.04
# 10322  Freight Included in Commodity Cost                    134.03
# 10323  Freight Included in Commodity Cost                     85.82
#
#       po_sent_to_vendor_date_raw pq_first_sent_to_client_date_raw  \
# 0              Date Not Captured                   Pre-PQ Process
# 1              Date Not Captured                   Pre-PQ Process
# 2              Date Not Captured                   Pre-PQ Process
# 3              Date Not Captured                   Pre-PQ Process
# 4              Date Not Captured                   Pre-PQ Process
# ...                          ...                              ...
# 10319             N/A - From RDC                       10/16/2014
# 10320             N/A - From RDC                       10/24/2014
# 10321             N/A - From RDC                        8/12/2014
# 10322             N/A - From RDC                         7/1/2015
# 10323             N/A - From RDC                       10/16/2014
#
#       invalid_delivery weight_kg_numeric_x freight_cost_usd_numeric_x  \
# 0                False                13.0                     780.34
# 1                False               358.0                    4521.50
# 2                False               171.0                    1653.78
# 3                False              1855.0                   16007.06
# 4                False              7590.0                   45450.08
# ...                ...                 ...                        ...
# 10319            False                 NaN                        NaN
# 10320            False                 NaN                        NaN
# 10321            False                 NaN                        NaN
# 10322            False              1392.0                        NaN
# 10323            False                 NaN                        NaN
#
#       asn_reference weight_kg_numeric_y freight_cost_usd_numeric_y
# 0               NaN                13.0                     780.34
# 1               NaN               358.0                    4521.50
# 2               NaN               171.0                    1653.78
# 3               NaN              1855.0                   16007.06
# 4               NaN              7590.0                   45450.08
# ...             ...                 ...                        ...
# 10319       DN-4307             25880.0                   46111.55
# 10320       DN-4313              4426.0                   14734.92
# 10321           NaN             85128.0                        NaN
# 10322           NaN              1392.0                        NaN
# 10323           NaN              3595.0                        NaN
#
# [10324 rows x 41 columns]

# %%
df.loc[df["freight_cost_usd_numeric_y"].isna()]
# Out:
#           id project_code            pq_# po___so_# asn_dn_#  \
# 6         44   110-ZM-T01  Pre-PQ Process  SCMS-139  ASN-130
# 9         47   110-ZM-T01  Pre-PQ Process  SCMS-165  ASN-199
# 10        60   110-ZM-T01  Pre-PQ Process  SCMS-221  ASN-223
# 12        62   102-NG-T01  Pre-PQ Process  SCMS-230  ASN-144
# 15        68   113-ZW-T01  Pre-PQ Process  SCMS-308  ASN-285
# ...      ...          ...             ...       ...      ...
# 10190  86604   102-DO-T30       FPQ-12902  SO-46510  DN-3325
# 10300  86797   114-UG-T30       FPQ-15639  SO-50670  DN-4215
# 10321  86821   110-ZM-T30       FPQ-14784  SO-49600  DN-4316
# 10322  86822   200-ZW-T30       FPQ-16523  SO-51680  DN-4334
# 10323  86823   103-ZW-T30       FPQ-15197  SO-50022  DN-4336
#
#                   country managed_by  fulfill_via vendor_inco_term  \
# 6                  Zambia   PMO - US  Direct Drop              DDU
# 9                  Zambia   PMO - US  Direct Drop              CIP
# 10                 Zambia   PMO - US  Direct Drop              CIP
# 12                Nigeria   PMO - US  Direct Drop              EXW
# 15               Zimbabwe   PMO - US  Direct Drop              CIP
# ...                   ...        ...          ...              ...
# 10190  Dominican Republic   PMO - US     From RDC   N/A - From RDC
# 10300              Uganda   PMO - US     From RDC   N/A - From RDC
# 10321              Zambia   PMO - US     From RDC   N/A - From RDC
# 10322            Zimbabwe   PMO - US     From RDC   N/A - From RDC
# 10323            Zimbabwe   PMO - US     From RDC   N/A - From RDC
#
#       shipment_mode  ...                  freight_cost_(usd)  \
# 6               Air  ...  Freight Included in Commodity Cost
# 9               Air  ...  Freight Included in Commodity Cost
# 10              Air  ...  Freight Included in Commodity Cost
# 12              Air  ...                 Invoiced Separately
# 15              Air  ...  Freight Included in Commodity Cost
# ...             ...  ...                                 ...
# 10190           Air  ...                 Invoiced Separately
# 10300         Truck  ...  Freight Included in Commodity Cost
# 10321         Truck  ...  Freight Included in Commodity Cost
# 10322         Truck  ...  Freight Included in Commodity Cost
# 10323         Truck  ...  Freight Included in Commodity Cost
#
#       line_item_insurance_(usd) po_sent_to_vendor_date_raw  \
# 6                           NaN          Date Not Captured
# 9                           NaN                 11/13/2006
# 10                          NaN                  12/1/2006
# 12                          NaN          Date Not Captured
# 15                          NaN                  1/10/2007
# ...                         ...                        ...
# 10190                      0.00             N/A - From RDC
# 10300                    196.88             N/A - From RDC
# 10321                   5284.04             N/A - From RDC
# 10322                    134.03             N/A - From RDC
# 10323                     85.82             N/A - From RDC
#
#       pq_first_sent_to_client_date_raw invalid_delivery weight_kg_numeric_x  \
# 6                       Pre-PQ Process            False               328.0
# 9                       Pre-PQ Process            False               643.0
# 10                      Pre-PQ Process            False               643.0
# 12                      Pre-PQ Process            False                 NaN
# 15                      Pre-PQ Process            False                 NaN
# ...                                ...              ...                 ...
# 10190                        8/29/2013            False                 NaN
# 10300                       12/22/2014            False                 NaN
# 10321                        8/12/2014            False                 NaN
# 10322                         7/1/2015            False              1392.0
# 10323                       10/16/2014            False                 NaN
#
#       freight_cost_usd_numeric_x asn_reference weight_kg_numeric_y  \
# 6                            NaN           NaN               328.0
# 9                            NaN           NaN               643.0
# 10                           NaN           NaN               643.0
# 12                           NaN           NaN                 NaN
# 15                           NaN           NaN                 NaN
# ...                          ...           ...                 ...
# 10190                        NaN           NaN                 NaN
# 10300                        NaN           NaN              8221.0
# 10321                        NaN           NaN             85128.0
# 10322                        NaN           NaN              1392.0
# 10323                        NaN           NaN              3595.0
#
#       freight_cost_usd_numeric_y
# 6                            NaN
# 9                            NaN
# 10                           NaN
# 12                           NaN
# 15                           NaN
# ...                          ...
# 10190                        NaN
# 10300                        NaN
# 10321                        NaN
# 10322                        NaN
# 10323                        NaN
#
# [1786 rows x 41 columns]

# %%
# Drop and rename weight and freight fields
df = df.drop(columns = ["weight_(kilograms)", "freight_cost_(usd)", "weight_kg_numeric_x", 
                        "freight_cost_usd_numeric_x", "asn_reference"])

# Rename weight and freight fields
df.rename(columns = {"weight_kg_numeric_y": "weight_kg", "freight_cost_usd_numeric_y": "freight_cost_usd"}, inplace = True)
df
# Out:
#           id project_code            pq_# po___so_# asn_dn_#        country  \
# 0          1   100-CI-T01  Pre-PQ Process    SCMS-4    ASN-8  Côte D'Ivoire
# 1          3   108-VN-T01  Pre-PQ Process   SCMS-13   ASN-85        Vietnam
# 2          4   100-CI-T01  Pre-PQ Process   SCMS-20   ASN-14  Côte D'Ivoire
# 3         15   108-VN-T01  Pre-PQ Process   SCMS-78   ASN-50        Vietnam
# 4         16   108-VN-T01  Pre-PQ Process   SCMS-81   ASN-55        Vietnam
# ...      ...          ...             ...       ...      ...            ...
# 10319  86818   103-ZW-T30       FPQ-15197  SO-50020  DN-4307       Zimbabwe
# 10320  86819   104-CI-T30       FPQ-15259  SO-50102  DN-4313  Côte D'Ivoire
# 10321  86821   110-ZM-T30       FPQ-14784  SO-49600  DN-4316         Zambia
# 10322  86822   200-ZW-T30       FPQ-16523  SO-51680  DN-4334       Zimbabwe
# 10323  86823   103-ZW-T30       FPQ-15197  SO-50022  DN-4336       Zimbabwe
#
#       managed_by  fulfill_via vendor_inco_term shipment_mode  ... pack_price  \
# 0       PMO - US  Direct Drop              EXW           Air  ...      29.00
# 1       PMO - US  Direct Drop              EXW           Air  ...       6.20
# 2       PMO - US  Direct Drop              FCA           Air  ...      80.00
# 3       PMO - US  Direct Drop              EXW           Air  ...       3.99
# 4       PMO - US  Direct Drop              EXW           Air  ...       3.20
# ...          ...          ...              ...           ...  ...        ...
# 10319   PMO - US     From RDC   N/A - From RDC         Truck  ...       3.60
# 10320   PMO - US     From RDC   N/A - From RDC         Truck  ...       6.52
# 10321   PMO - US     From RDC   N/A - From RDC         Truck  ...       9.99
# 10322   PMO - US     From RDC   N/A - From RDC         Truck  ...       6.52
# 10323   PMO - US     From RDC   N/A - From RDC         Truck  ...       1.99
#
#       unit_price              manufacturing_site first_line_designation  \
# 0           0.97      Ranbaxy Fine Chemicals LTD                    Yes
# 1           0.03       Aurobindo Unit III, India                    Yes
# 2           0.80   ABBVIE GmbH & Co.KG Wiesbaden                    Yes
# 3           0.07   Ranbaxy, Paonta Shahib, India                    Yes
# 4           0.05       Aurobindo Unit III, India                    Yes
# ...          ...                             ...                    ...
# 10319       0.06      Mylan,  H-12 & H-13, India                     No
# 10320       0.11    Hetero Unit III Hyderabad IN                     No
# 10321       0.33   Cipla Ltd A-42 MIDC Mahar. IN                     No
# 10322       0.11  Mylan (formerly Matrix) Nashik                    Yes
# 10323       0.03               Cipla, Goa, India                     No
#
#       line_item_insurance_(usd) po_sent_to_vendor_date_raw  \
# 0                           NaN          Date Not Captured
# 1                           NaN          Date Not Captured
# 2                           NaN          Date Not Captured
# 3                           NaN          Date Not Captured
# 4                           NaN          Date Not Captured
# ...                         ...                        ...
# 10319                    705.79             N/A - From RDC
# 10320                    161.71             N/A - From RDC
# 10321                   5284.04             N/A - From RDC
# 10322                    134.03             N/A - From RDC
# 10323                     85.82             N/A - From RDC
#
#       pq_first_sent_to_client_date_raw invalid_delivery weight_kg  \
# 0                       Pre-PQ Process            False      13.0
# 1                       Pre-PQ Process            False     358.0
# 2                       Pre-PQ Process            False     171.0
# 3                       Pre-PQ Process            False    1855.0
# 4                       Pre-PQ Process            False    7590.0
# ...                                ...              ...       ...
# 10319                       10/16/2014            False   25880.0
# 10320                       10/24/2014            False    4426.0
# 10321                        8/12/2014            False   85128.0
# 10322                         7/1/2015            False    1392.0
# 10323                       10/16/2014            False    3595.0
#
#       freight_cost_usd
# 0               780.34
# 1              4521.50
# 2              1653.78
# 3             16007.06
# 4             45450.08
# ...                ...
# 10319         46111.55
# 10320         14734.92
# 10321              NaN
# 10322              NaN
# 10323              NaN
#
# [10324 rows x 36 columns]

# %%
# Weight and freight consistency checks
df["inconsistency_check"] = ((df["freight_cost_usd"] > 0) & 
                             (df["weight_kg"].isna()) | (df["weight_kg"] == 0))
df.loc[df["inconsistency_check"] == True]
# Out:
#           id project_code            pq_#    po___so_#   asn_dn_#  \
# 114     1115   116-ZA-T01  Pre-PQ Process   SCMS-47500   ASN-4332
# 257     2481   116-ZA-T01  Pre-PQ Process   SCMS-47500   ASN-4332
# 378     3745   116-ZA-T01  Pre-PQ Process   SCMS-41050   ASN-3635
# 501     5049   116-ZA-T01  Pre-PQ Process   SCMS-41160   ASN-3760
# 629     6400   116-ZA-T01  Pre-PQ Process   SCMS-41050   ASN-3635
# 631     6402   116-ZA-T01  Pre-PQ Process   SCMS-41160   ASN-3760
# 643     6437   116-ZA-T01  Pre-PQ Process   SCMS-47500   ASN-4332
# 644     6438   116-ZA-T01  Pre-PQ Process   SCMS-47500   ASN-4332
# 645     6439   116-ZA-T01  Pre-PQ Process   SCMS-47500   ASN-4332
# 700     7007   108-VN-T01  Pre-PQ Process   SCMS-19630   ASN-1718
# 752     7728   116-ZA-T01  Pre-PQ Process   SCMS-41050   ASN-3635
# 880     9081   116-ZA-T01  Pre-PQ Process   SCMS-47500   ASN-4332
# 991    10353   116-ZA-T01  Pre-PQ Process   SCMS-41160   ASN-3760
# 992    10354   116-ZA-T01  Pre-PQ Process   SCMS-41160   ASN-3760
# 1034   10549   111-MZ-T01  Pre-PQ Process       SO-293      DN-44
# 1223   10819   109-TZ-T01  Pre-PQ Process       SO-420     DN-133
# 1224   10820   111-MZ-T01  Pre-PQ Process       SO-293      DN-44
# 1225   10821   111-MZ-T01  Pre-PQ Process       SO-293      DN-44
# 1439   11109   111-MZ-T01  Pre-PQ Process       SO-293      DN-44
# 1616   11379   110-ZM-T01  Pre-PQ Process       SO-536     DN-136
# 1630   11401   107-RW-T01  Pre-PQ Process       SO-240     DN-150
# 1631   11402   107-RW-T01  Pre-PQ Process       SO-240     DN-150
# 1842   11708   111-MZ-T01  Pre-PQ Process       SO-458      DN-90
# 1846   11712   100-HT-T01  Pre-PQ Process       SO-504     DN-112
# 1852   11719   111-MZ-T01  Pre-PQ Process       SO-293      DN-44
# 2083   12058   109-TZ-T01  Pre-PQ Process       SO-306     DN-144
# 2287   12341   111-MZ-T01  Pre-PQ Process       SO-293      DN-44
# 2288   12342   111-MZ-T01  Pre-PQ Process       SO-293      DN-44
# 2479   12622   111-MZ-T01  Pre-PQ Process       SO-325      DN-18
# 2482   12630   111-MZ-T01  Pre-PQ Process       SO-380      DN-88
# 2495   12654   109-TZ-T01  Pre-PQ Process       SO-306     DN-144
# 2737   13900   103-CM-T30       FPQ-12659  SCMS-201930  ASN-21679
# 2799   14874   161-ZA-T30        FPQ-5648   SCMS-75520   ASN-8545
# 3284   23750   109-TZ-T30       FPQ-11919  SCMS-205460  ASN-22365
# 3364   25085   117-ET-T30        FPQ-6608   SCMS-92050  ASN-10239
# 4126   38949   161-ZA-T30        FPQ-6262   SCMS-83880  ASN-10012
# 4976   54248   161-ZA-T30        FPQ-6262   SCMS-91340  ASN-10011
# 5957   71241   103-CM-T30       FPQ-12659  SCMS-201930  ASN-21679
# 6420   79445   102-SD-T30        FPQ-8264  SCMS-121841  ASN-12829
# 6560   81988   161-ZA-T30        FPQ-5447   SCMS-70130   ASN-7086
# 7342   83163   111-MZ-T30       FPQ-11033     SO-43775    DN-3338
# 8740   84854   151-NG-T30       FPQ-11864     SO-44931    DN-3324
# 9007   85192   100-BZ-T30        FPQ-7883     SO-40050    DN-2267
# 9193   85399   151-NG-T30       FPQ-11864     SO-44931    DN-3324
# 10188  86602   151-NG-T30       FPQ-11864     SO-44931    DN-3324
# 10189  86603   151-NG-T30       FPQ-11864     SO-44931    DN-3324
#
#             country managed_by  fulfill_via vendor_inco_term shipment_mode  \
# 114    South Africa   PMO - US  Direct Drop              DDP         Truck
# 257    South Africa   PMO - US  Direct Drop              DDP         Truck
# 378    South Africa   PMO - US  Direct Drop              DDP           Air
# 501    South Africa   PMO - US  Direct Drop              DDP           Air
# 629    South Africa   PMO - US  Direct Drop              DDP           Air
# 631    South Africa   PMO - US  Direct Drop              DDP           Air
# 643    South Africa   PMO - US  Direct Drop              DDP         Truck
# 644    South Africa   PMO - US  Direct Drop              DDP         Truck
# 645    South Africa   PMO - US  Direct Drop              DDP         Truck
# 700         Vietnam   PMO - US  Direct Drop              DDU         Truck
# 752    South Africa   PMO - US  Direct Drop              DDP           Air
# 880    South Africa   PMO - US  Direct Drop              DDP         Truck
# 991    South Africa   PMO - US  Direct Drop              DDP           Air
# 992    South Africa   PMO - US  Direct Drop              DDP           Air
# 1034     Mozambique   PMO - US     From RDC   N/A - From RDC           Air
# 1223       Tanzania   PMO - US     From RDC   N/A - From RDC           Air
# 1224     Mozambique   PMO - US     From RDC   N/A - From RDC           Air
# 1225     Mozambique   PMO - US     From RDC   N/A - From RDC           Air
# 1439     Mozambique   PMO - US     From RDC   N/A - From RDC           Air
# 1616         Zambia   PMO - US     From RDC   N/A - From RDC           Air
# 1630         Rwanda   PMO - US     From RDC   N/A - From RDC           Air
# 1631         Rwanda   PMO - US     From RDC   N/A - From RDC           Air
# 1842     Mozambique   PMO - US     From RDC   N/A - From RDC           Air
# 1846          Haiti   PMO - US     From RDC   N/A - From RDC           Air
# 1852     Mozambique   PMO - US     From RDC   N/A - From RDC           Air
# 2083       Tanzania   PMO - US     From RDC   N/A - From RDC           Air
# 2287     Mozambique   PMO - US     From RDC   N/A - From RDC           Air
# 2288     Mozambique   PMO - US     From RDC   N/A - From RDC           Air
# 2479     Mozambique   PMO - US     From RDC   N/A - From RDC           Air
# 2482     Mozambique   PMO - US     From RDC   N/A - From RDC           Air
# 2495       Tanzania   PMO - US     From RDC   N/A - From RDC           Air
# 2737       Cameroon   PMO - US  Direct Drop              EXW           Air
# 2799   South Africa   PMO - US  Direct Drop              DDP           Air
# 3284       Tanzania   PMO - US  Direct Drop              EXW           Air
# 3364       Ethiopia   PMO - US  Direct Drop              EXW           Air
# 4126   South Africa   PMO - US  Direct Drop              DDP           Air
# 4976   South Africa   PMO - US  Direct Drop              DDP           Air
# 5957       Cameroon   PMO - US  Direct Drop              EXW           Air
# 6420          Sudan   PMO - US  Direct Drop              EXW           Air
# 6560   South Africa   PMO - US  Direct Drop              DDP         Truck
# 7342     Mozambique   PMO - US     From RDC   N/A - From RDC         Truck
# 8740        Nigeria   PMO - US     From RDC   N/A - From RDC   Air Charter
# 9007         Belize   PMO - US     From RDC   N/A - From RDC           Air
# 9193        Nigeria   PMO - US     From RDC   N/A - From RDC   Air Charter
# 10188       Nigeria   PMO - US     From RDC   N/A - From RDC   Air Charter
# 10189       Nigeria   PMO - US     From RDC   N/A - From RDC   Air Charter
#
#        ... unit_price                    manufacturing_site  \
# 114    ...       0.33             Aurobindo Unit III, India
# 257    ...       0.07                    BMS Meymac, France
# 378    ...       0.08               MSD Midrand, J'burg, SA
# 501    ...       0.22                            GSK Aranda
# 629    ...       0.02             Aurobindo Unit III, India
# 631    ...       0.02              GSK Mississauga (Canada)
# 643    ...       0.12             Aurobindo Unit III, India
# 644    ...       0.01             Aurobindo Unit III, India
# 645    ...       0.04             Aurobindo Unit III, India
# 700    ...       0.69        Gilead(Nycomed) Oranienburg DE
# 752    ...       0.10             Aurobindo Unit III, India
# 880    ...       0.03             Aurobindo Unit III, India
# 991    ...       0.09  GSK Cape Town Factory (South Africa)
# 992    ...       0.03              GSK Mississauga (Canada)
# 1034   ...       0.28                           Roche Basel
# 1223   ...       0.80           Standard Diagnostics, Korea
# 1224   ...       0.36        MSD Manati, Puerto Rico, (USA)
# 1225   ...       0.57        Gilead(Nycomed) Oranienburg DE
# 1439   ...       0.09             Aurobindo Unit III, India
# 1616   ...       0.80           Standard Diagnostics, Korea
# 1630   ...       0.70          Premier Med. Corp Ltd. India
# 1631   ...       1.39                  Trinity Biotech, Plc
# 1842   ...       0.14         Ranbaxy, Paonta Shahib, India
# 1846   ...       4.00             Pacific Biotech, Thailand
# 1852   ...       0.29             Aurobindo Unit III, India
# 2083   ...       1.60                  Trinity Biotech, Plc
# 2287   ...       0.56             Aurobindo Unit III, India
# 2288   ...       0.01                     Cipla, Goa, India
# 2479   ...       0.01                     Cipla, Goa, India
# 2482   ...       0.11        MSD Manati, Puerto Rico, (USA)
# 2495   ...       0.80           Standard Diagnostics, Korea
# 2737   ...       0.72               Alere Medical Co., Ltd.
# 2799   ...       0.06              GSK Mississauga (Canada)
# 3284   ...       1.60                  Trinity Biotech, Plc
# 3364   ...       1.60                  Trinity Biotech, Plc
# 4126   ...       0.04              GSK Mississauga (Canada)
# 4976   ...       0.04              GSK Mississauga (Canada)
# 5957   ...       5.00               Alere Medical Co., Ltd.
# 6420   ...       0.08               Alere Medical Co., Ltd.
# 6560   ...       0.01             Aurobindo Unit III, India
# 7342   ...       0.37        Mylan (formerly Matrix) Nashik
# 8740   ...       0.14          Hetero Unit III Hyderabad IN
# 9007   ...       0.01             Aurobindo Unit III, India
# 9193   ...       0.14            Strides, Bangalore, India.
# 10188  ...       0.14        Mylan (formerly Matrix) Nashik
# 10189  ...       0.14             Aurobindo Unit III, India
#
#       first_line_designation line_item_insurance_(usd)  \
# 114                      Yes                     38.75
# 257                       No                      0.59
# 378                      Yes                      1.67
# 501                      Yes                     12.85
# 629                       No                      0.16
# 631                       No                      1.66
# 643                       No                     27.75
# 644                       No                      1.63
# 645                       No                      1.47
# 700                      Yes                     65.15
# 752                       No                      0.86
# 880                       No                      2.37
# 991                       No                     20.50
# 992                       No                      1.86
# 1034                     Yes                       NaN
# 1223                     Yes                       NaN
# 1224                      No                       NaN
# 1225                      No                       NaN
# 1439                      No                       NaN
# 1616                     Yes                       NaN
# 1630                     Yes                       NaN
# 1631                      No                       NaN
# 1842                     Yes                       NaN
# 1846                     Yes                       NaN
# 1852                      No                       NaN
# 2083                     Yes                       NaN
# 2287                      No                       NaN
# 2288                      No                       NaN
# 2479                     Yes                       NaN
# 2482                     Yes                       NaN
# 2495                      No                       NaN
# 2737                     Yes                     10.71
# 2799                     Yes                    845.32
# 3284                     Yes                      0.12
# 3364                     Yes                     17.74
# 4126                     Yes                    864.12
# 4976                     Yes                    259.24
# 5957                      No                      0.31
# 6420                     Yes                      0.05
# 6560                     Yes                    109.16
# 7342                     Yes                    210.28
# 8740                     Yes                    188.73
# 9007                     Yes                      1.04
# 9193                      No                    849.08
# 10188                     No                     79.13
# 10189                     No                   1698.15
#
#       po_sent_to_vendor_date_raw pq_first_sent_to_client_date_raw  \
# 114                     4/2/2009                   Pre-PQ Process
# 257                     4/2/2009                   Pre-PQ Process
# 378            Date Not Captured                   Pre-PQ Process
# 501            Date Not Captured                   Pre-PQ Process
# 629            Date Not Captured                   Pre-PQ Process
# 631            Date Not Captured                   Pre-PQ Process
# 643                     4/2/2009                   Pre-PQ Process
# 644                     4/2/2009                   Pre-PQ Process
# 645                     4/2/2009                   Pre-PQ Process
# 700                    3/21/2008                   Pre-PQ Process
# 752            Date Not Captured                   Pre-PQ Process
# 880                     4/2/2009                   Pre-PQ Process
# 991            Date Not Captured                   Pre-PQ Process
# 992            Date Not Captured                   Pre-PQ Process
# 1034              N/A - From RDC                   Pre-PQ Process
# 1223              N/A - From RDC                   Pre-PQ Process
# 1224              N/A - From RDC                   Pre-PQ Process
# 1225              N/A - From RDC                   Pre-PQ Process
# 1439              N/A - From RDC                   Pre-PQ Process
# 1616              N/A - From RDC                   Pre-PQ Process
# 1630              N/A - From RDC                   Pre-PQ Process
# 1631              N/A - From RDC                   Pre-PQ Process
# 1842              N/A - From RDC                   Pre-PQ Process
# 1846              N/A - From RDC                   Pre-PQ Process
# 1852              N/A - From RDC                   Pre-PQ Process
# 2083              N/A - From RDC                   Pre-PQ Process
# 2287              N/A - From RDC                   Pre-PQ Process
# 2288              N/A - From RDC                   Pre-PQ Process
# 2479              N/A - From RDC                   Pre-PQ Process
# 2482              N/A - From RDC                   Pre-PQ Process
# 2495              N/A - From RDC                   Pre-PQ Process
# 2737                    8/6/2013                        7/26/2013
# 2799                   6/16/2010                         6/2/2010
# 3284                   9/11/2013                        3/25/2013
# 3364                  11/24/2010                        11/9/2010
# 4126                   9/21/2010                        8/31/2010
# 4976                  11/19/2010                        8/31/2010
# 5957                    8/6/2013                        7/26/2013
# 6420                   9/14/2011                         9/7/2011
# 6560                   4/23/2010                         4/1/2010
# 7342              N/A - From RDC                       11/12/2012
# 8740              N/A - From RDC                        3/14/2013
# 9007              N/A - From RDC                        6/17/2011
# 9193              N/A - From RDC                        3/14/2013
# 10188             N/A - From RDC                        3/14/2013
# 10189             N/A - From RDC                        3/14/2013
#
#       invalid_delivery weight_kg freight_cost_usd inconsistency_check
# 114              False       NaN          3134.85                True
# 257              False       NaN          3134.85                True
# 378              False       NaN          4230.75                True
# 501              False       NaN          1521.40                True
# 629              False       NaN          4230.75                True
# 631              False       NaN          1521.40                True
# 643              False       NaN          3134.85                True
# 644              False       NaN          3134.85                True
# 645              False       NaN          3134.85                True
# 700              False       NaN          1401.49                True
# 752              False       NaN          4230.75                True
# 880              False       NaN          3134.85                True
# 991              False       NaN          1521.40                True
# 992              False       NaN          1521.40                True
# 1034             False       NaN          7364.30                True
# 1223             False       NaN         12740.42                True
# 1224             False       NaN          7364.30                True
# 1225             False       NaN          7364.30                True
# 1439             False       NaN          7364.30                True
# 1616             False       NaN          1250.72                True
# 1630             False       NaN          2805.51                True
# 1631             False       NaN          2805.51                True
# 1842             False       NaN           596.40                True
# 1846             False       NaN           977.64                True
# 1852             False       NaN          7364.30                True
# 2083             False       NaN          2297.00                True
# 2287             False       NaN          7364.30                True
# 2288             False       NaN          7364.30                True
# 2479             False       NaN          2123.04                True
# 2482             False       NaN           679.60                True
# 2495             False       NaN          2297.00                True
# 2737             False       NaN          1090.87                True
# 2799             False       NaN          7707.42                True
# 3284             False       0.0          1002.35                True
# 3364             False       NaN          1921.14                True
# 4126             False       NaN         11770.87                True
# 4976             False       NaN         12474.06                True
# 5957             False       NaN          1090.87                True
# 6420             False       NaN           878.34                True
# 6560             False       NaN          3908.56                True
# 7342             False       NaN          5902.40                True
# 8740             False       NaN         41352.75                True
# 9007             False       NaN          1959.61                True
# 9193             False       NaN         41352.75                True
# 10188            False       NaN         41352.75                True
# 10189            False       NaN         41352.75                True
#
# [46 rows x 37 columns]

# %%
# Create logistics KPIs
df["lead_time_days"] = (df["delivered_to_client_date"] - df["po_sent_to_vendor_date"]).dt.days
df["schedule_delay_days"] = (df["delivered_to_client_date"] - df["scheduled_delivery_date"]).dt.days
df["on_time"] = df["schedule_delay_days"] <= 0
df["freight_per_kg"] = df["freight_cost_usd"] / df["weight_kg"].replace(0, np.nan)

# Time features
df["delivered_month"] = df["delivered_to_client_date"].dt.to_period("M").astype(str)
df["delivered_year"] = df["delivered_to_client_date"].dt.year

# %%
# Missing values summary
df.isna().mean().sort_values(ascending=False).head(15)
# Out:
# po_sent_to_vendor_date          0.555211
# lead_time_days                  0.555211
# pq_first_sent_to_client_date    0.259686
# freight_per_kg                  0.177451
# freight_cost_usd                0.172995
# dosage                          0.168152
# weight_kg                       0.155366
# shipment_mode                   0.034870
# line_item_insurance_(usd)       0.027799
# schedule_delay_days             0.000000
# line_item_value                 0.000000
# pack_price                      0.000000
# unit_price                      0.000000
# manufacturing_site              0.000000
# first_line_designation          0.000000
# dtype: float64

# %%
# Logical consistency checks
# Negative lead time?
df[df["lead_time_days"] < 0].shape[0]

# Freight per kg extremely high?
df["freight_per_kg"].describe(percentiles=[.9, .95, .99])
# Out:
# count     8492.000000
# mean        31.163999
# std        496.770891
# min          0.000539
# 50%          6.324641
# 90%         27.564314
# 95%         59.078545
# 99%        329.722450
# max      31087.705000
# Name: freight_per_kg, dtype: float64

# %%
# Data quality summary
print("Final dataset shape:", df.shape)

print("\nMissing values (top 10):")
print(df.isna().sum().sort_values(ascending=False).head(10))

print("\nInvalid date sequences:", df["invalid_delivery"].sum())
print("Freight-weight mismatches:", df["inconsistency_check"].sum())
# Out:
# Final dataset shape: (10324, 43)
#
# Missing values (top 10):
# po_sent_to_vendor_date          5732
# lead_time_days                  5732
# pq_first_sent_to_client_date    2681
# freight_per_kg                  1832
# freight_cost_usd                1786
# dosage                          1736
# weight_kg                       1604
# shipment_mode                    360
# line_item_insurance_(usd)        287
# schedule_delay_days                0
# dtype: int64
#
# Invalid date sequences: 5
# Freight-weight mismatches: 46

# %%
# Format date columns
date_cols = ["pq_first_sent_to_client_date", "po_sent_to_vendor_date", "scheduled_delivery_date", "delivered_to_client_date", "delivery_recorded_date"]

for col in date_cols:
    if col in df.columns and pd.api.types.is_datetime64_any_dtype(df[col]):
        df[col] = df[col].dt.strftime("%d/%m/%y")

df[["po_sent_to_vendor_date","delivered_to_client_date", "lead_time_days","schedule_delay_days","on_time", "freight_cost_usd","weight_kg","freight_per_kg"]].head(10)
# Out:
#   po_sent_to_vendor_date delivered_to_client_date  lead_time_days  \
# 0                    NaN                 02/06/06             NaN
# 1                    NaN                 14/11/06             NaN
# 2                    NaN                 27/08/06             NaN
# 3                    NaN                 01/09/06             NaN
# 4                    NaN                 11/08/06             NaN
# 5                    NaN                 28/09/06             NaN
# 6                    NaN                 08/01/07             NaN
# 7                    NaN                 24/11/06             NaN
# 8                    NaN                 07/12/06             NaN
# 9               13/11/06                 30/01/07            78.0
#
#    schedule_delay_days  on_time  freight_cost_usd  weight_kg  freight_per_kg
# 0                    0     True            780.34       13.0       60.026154
# 1                    0     True           4521.50      358.0       12.629888
# 2                    0     True           1653.78      171.0        9.671228
# 3                    0     True          16007.06     1855.0        8.629143
# 4                    0     True          45450.08     7590.0        5.988153
# 5                    0     True           5920.42      504.0       11.746865
# 6                    0     True               NaN      328.0             NaN
# 7                    0     True           6212.41     1478.0        4.203254
# 8                    0     True           4861.14      479.0       10.148518
# 9                    0     True               NaN      643.0             NaN

# %%
df.to_csv("../Data/cleaned_supply_chain_data.csv", index=False)
